# %% [markdown]
# # Introduction
# In this tutorial, we will use `torch.package` to export and import [a DCGAN model for generating 64x64 images of fashion models](https://pytorch.org/hub/facebookresearch_pytorch-gan-zoo_dcgan/) hosted on Torch Hub.
#
# ![DCGAN](https://pytorch.org/assets/images/dcgan_fashionGen.jpg)

# %% [markdown]
# # Install the correct version of PyTorch
#
# Install the nightly build of PyTorch to get access to the latest features for `torch.package`.

# %% [markdown]
# # Get and run the model
#
# First, get the model using the example code from the Torch Hub page for DCGAN.

# %%
import torch

use_gpu = True if torch.cuda.is_available() else False
model = torch.hub.load('facebookresearch/pytorch_GAN_zoo:hub', 'DCGAN', pretrained=True, useGPU=use_gpu)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorch_GAN_zoo_hub
# Average network found !

# %% [markdown]
# Now, modify the example code slightly to create a helper function that runs a given model and shows the generated output. This function will be useful later on to test that the imported version of the model generates images similar to the one that was exported.

# %%
def run_model(model):
  num_images = 64
  noise, _ = model.buildNoiseData(num_images)
  with torch.no_grad():
    generated_images = model.test(noise)

  # let's plot these images using torchvision and matplotlib
  import matplotlib.pyplot as plt
  import torchvision
  plt.imshow(torchvision.utils.make_grid(generated_images).permute(1, 2, 0).cpu().numpy())

# %% [markdown]
# Finally, pass the model to this `run_model` function to make sure it works.

# %%
run_model(model)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9821109..1.0].

# %% [markdown]
# Having confirmed that the model works and produces sensible output, let's see how it can be exported using `torch.package`.

# %% [markdown]
# # Export the model
# To export the model, use `torch.package.PackageExporter` to specify where the package should be created and everything that should be stored in it.

# %%
from torch import package

path = "/tmp/dcgan.pt"
package_name = "dcgan"
resource_name = "model.pkl"

with package.PackageExporter(path) as exp:
    exp.save_pickle(package_name, resource_name, model)
# Out:
# ---------------------------------------------------------------------------
# PackagingError                            Traceback (most recent call last)
# /tmp/ipykernel_9031/1050729100.py in <cell line: 0>()
#       5 resource_name = "model.pkl"
#       6
# ----> 7 with package.PackageExporter(path) as exp:
#       8     exp.save_pickle(package_name, resource_name, model)
#       9
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in __exit__(self, exc_type, exc_value, traceback)
#     969             return
#     970
# --> 971         self.close()
#     972
#     973     def _write(self, filename, str_or_bytes):
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in close(self)
#    1073                 ...
#    1074         """
# -> 1075         self._execute_dependency_graph()
#    1076         self._write_python_version()
#    1077
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in _execute_dependency_graph(self)
#    1010         modules and executes it, writing to the ZIP archive.
#    1011         """
# -> 1012         self._validate_dependency_graph()
#    1013
#    1014         extern_modules = []
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in _validate_dependency_graph(self)
#     992         for attrs in self.dependency_graph.nodes.values():
#     993             if "error" in attrs:
# --> 994                 raise PackagingError(self.dependency_graph, debug=self.debug)
#     995
#     996         # 2. Check that all patterns for which allow_empty=False have been matched at least once.
#
# PackagingError:
# * Module did not match against any action pattern. Extern, mock, or intern it.
#     models.DCGAN
#     models.utils.config
#     models.loss_criterions.ac_criterion
#     models.loss_criterions.base_loss_criterions
#     models.networks.DCGAN_nets
#
# Set debug=True when invoking PackageExporter for a visualization of where broken modules are coming from!

# %% [markdown]
# Oh no!
#
# In order to create a hermetic package, `PackageExporter` tries to access the source code of all dependencies needed by the modules and objects that will be saved. It skips any dependencies marked as `extern`, `mock`, and not marked as `intern`. Interns, externs, and mocks can be specified by name or by glob. Based on the error message above, `models.**` needs to be interned so that all the listed modules, which are part of the model of interest, are packaged.

# %%
with package.PackageExporter(path) as exp:
    exp.intern("models.**")
    exp.save_pickle(package_name, resource_name, model)
# Out:
# ---------------------------------------------------------------------------
# PackagingError                            Traceback (most recent call last)
# /tmp/ipykernel_9031/258663292.py in <cell line: 0>()
# ----> 1 with package.PackageExporter(path) as exp:
#       2     exp.intern("models.**")
#       3     exp.save_pickle(package_name, resource_name, model)
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in __exit__(self, exc_type, exc_value, traceback)
#     969             return
#     970
# --> 971         self.close()
#     972
#     973     def _write(self, filename, str_or_bytes):
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in close(self)
#    1073                 ...
#    1074         """
# -> 1075         self._execute_dependency_graph()
#    1076         self._write_python_version()
#    1077
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in _execute_dependency_graph(self)
#    1010         modules and executes it, writing to the ZIP archive.
#    1011         """
# -> 1012         self._validate_dependency_graph()
#    1013
#    1014         extern_modules = []
#
# /usr/local/lib/python3.12/dist-packages/torch/package/package_exporter.py in _validate_dependency_graph(self)
#     992         for attrs in self.dependency_graph.nodes.values():
#     993             if "error" in attrs:
# --> 994                 raise PackagingError(self.dependency_graph, debug=self.debug)
#     995
#     996         # 2. Check that all patterns for which allow_empty=False have been matched at least once.
#
# PackagingError:
# * Module did not match against any action pattern. Extern, mock, or intern it.
#     numpy
#
# Set debug=True when invoking PackageExporter for a visualization of where broken modules are coming from!

# %% [markdown]
# The `numpy` module is not a core part of the model being packaged, and can be marked as `extern`:

# %%
with package.PackageExporter(path) as exp:
    exp.extern("numpy.**")
    exp.intern("models.**")
    exp.save_pickle(package_name, resource_name, model)

# %% [markdown]
# # Importing the model
#
# To import the model, use `torch.package.PackageImporter` to specify the path of the package and which resources should be loaded.

# %%
imp = package.PackageImporter(path)
loaded_model = imp.load_pickle(package_name, resource_name)

# %% [markdown]
# Then, call the previously defined `run_model` function to make sure the output matches.

# %%
run_model(loaded_model)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.97306913..1.0].

# %% [markdown]
# And that's it! You have successfully packaged and imported your first model!
